# %%
from IPython.display import Image

# %% [markdown]
# # 2.1 함수란
# 함수: 어떤 변수로부터 다른 변수로의 대응 관계를 정한 것

# %%
Image("../밑바닥3 그림과 수식/그림 2-1.png")

# %% [markdown]
# 위와 같이 노드들을 화살표로 연결해 계산 과정을 표현한 그림을 계산 그래프(computational graph)라고 한다.
# 여기서는 변수를 원으로, 함수를 사각형으로 표시한다.
